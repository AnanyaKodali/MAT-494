# %% [markdown]
# <a href="https://colab.research.google.com/github/AnanyaKodali/MAT-494/blob/main/2_2_Probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**2.2.1 Probability Axioms**

# %% [markdown]
# ### Sample Spaces and Events

# %% [markdown]
# **Definition 2.2.1**
#
# The sample space of an experiment, denoted by
# 𝑆, is the set of all possible outcomes of that experiment.

# %% [markdown]
# **Definition 2.2.2**
#
# An event is any subset of outcomes from the sample space 𝑆. An event is:
#
# * Simple if it consists of exactly one outcome.
# * Compound if it consists of more than one outcome.

# %% [markdown]
# ### Probability Axioms

# %% [markdown]
# **Definition 2.2.3**
#
# Given an experiment and a sample space 𝑆, the probability distribution is a function that assigns to each event 𝐴 a number 𝑃(𝐴), called the probability of the event 𝐴, which provides a measure of the chance that 𝐴 will occur. The probability assignments should satisfy the following axioms:
#
# 1.   Non-negativity: For any event 𝐴, $0 ≤ 𝑃(𝐴) ≤1.$
# 2.   Normalization: $𝑃(𝑆)= 1$
# 3. Additivity: If {$𝐴_i$} is an infinite collection of mutually exclusive events (i.e., $𝐴_i ∩ 𝐴_j =∅$ for $𝑖 ≠ 𝑗$), then:
# $𝑃(⋃_𝑖𝐴_𝑖) =∑_𝑖 𝑃(𝐴_𝑖)$
#
# From these axioms, several properties can be derived:
#
# 1. Complement Rule:
# $ 𝑃(𝐴^𝑐) = 1− 𝑃(𝐴)$, where $𝐴^𝑐$ is the complement of 𝐴 in 𝑆.
# 2. Subadditivity: For any two events 𝐴 and 𝐵:
# $𝑃(𝐴∪𝐵) = 𝑃(𝐴)+𝑃(𝐵)−𝑃(𝐴∩𝐵)$

# %% [markdown]
# **Example 2.2.1: Rolling a Die**
#
# Consider the simple experiment of rolling a fair six-sided die.
#
# * Sample Space: $𝑆 = {1,2,3,4,5,6}$
# * Each outcome is equally likely, so the probability of each simple event is:
# $𝑃({𝑖})= 1/6$, for $𝑖 = 1,2,3,4,5,6%$
#
# Define Events:
# 1. 𝐴: Rolling an even number. $𝐴 = {2,4,6}$
# 2. 𝐵: Rolling a number greater than 4. $𝐵 = {5,6}$
#
# Compute Probabilities:
#
# 1. $P(A)= 6/3 = 0.5$
# 2. $𝑃(B) = 2/6 ≈ 0.3333$
# 3. $P(A∩B)= 1/6 ≈ 0.1667$
# 4. $P(A∪B)=P(A)+P(B)−P(A∩B)= 4/6 ≈ 0.6667$
#
# Verification of Probability Axioms:
#
# * Non-negativity: All probabilities are between 0 and 1.
# * Normalization: $P(S)=1$
# * Additivity: The sum of probabilities of all mutually exclusive outcomes equals the probability of their union.

# %%
# Import necessary libraries
import numpy as np

# Define the sample space
S = {1, 2, 3, 4, 5, 6}

# Define events A and B
A = {2, 4, 6}  # Even numbers
B = {5, 6}     # Numbers greater than 4

# Calculate probabilities
P_A = len(A) / len(S)
P_B = len(B) / len(S)
P_A_and_B = len(A & B) / len(S)
P_A_or_B = P_A + P_B - P_A_and_B  # Inclusion-Exclusion Principle

# Output the probabilities
print(f"P(A) = {P_A}")
print(f"P(B) = {P_B}")
print(f"P(A ∩ B) = {P_A_and_B}")
print(f"P(A ∪ B) = {P_A_or_B}")
# Out:
# P(A) = 0.5
# P(B) = 0.3333333333333333
# P(A ∩ B) = 0.16666666666666666
# P(A ∪ B) = 0.6666666666666666

# %% [markdown]
# ##**2.2.2 Conditional Probability**

# %% [markdown]
# **Definition 2.2.4**
#
# For any two events 𝐴 and 𝐵 with $P(B)>0$, the conditional probability of 𝐴 given that 𝐵 has occurred is defined by:
#
# $P(A∣B)= P(A∩B)/ P(B)$
#
#
#
# This leads to the Multiplication Rule:
# $P(A∩B)=P(B)×P(A∣B)$

# %% [markdown]
# **Definition 2.2.5**
#
# Two events
# 𝐴 and 𝐵 are independent if: $P(A∩B)=P(A)×P(B)$

# %% [markdown]
# **Example 2.2.2**
#
# Using the die-rolling experiment:
#
# 1. Event $𝐴$ : Rolling an even number (${2,4,6}$)
# 2. Event $𝐵$ : Rolling a number greater than 4 (${5,6}$)
# 3. Event $𝐴∩𝐵$ : Rolling a 6 (${6}$)
#
# Compute $P(A∣B)$:
# * $P(A∣B)= P(A∩B)/ P(B) = (1/6)/(2/6) = 1/2$
# * So, given that we rolled a number greater than 4, there's a 50% chance it is even.
#
# Are $A$ and $𝐵$ independent?
# * Check if $P(A∩B)=P(A)×P(B)$:
# * $P(A)×P(B)=0.5×0.3333=0.1667$
# * Since $P(A∩B)=P(A)×P(B)$, events $𝐴$ and $𝐵$ are independent.

# %%
# Conditional Probability P(A|B)
P_A_given_B = P_A_and_B / P_B
print(f"P(A|B): {P_A_given_B}")

# Check for independence
if np.isclose(P_A_and_B, P_A * P_B):
    print("Events A and B are independent.")
else:
    print("Events A and B are dependent.")
# Out:
# P(A|B): 0.5
# Events A and B are independent.

# %% [markdown]
# ## **2.2.3 Discrete Random Variables**

# %% [markdown]
# **Definition 2.2.6**
#
# A random variable is a function that assigns a real number to each outcome in the sample space.

# %% [markdown]
# **Definition 2.2.7**
#
# A discrete random variable is a random variable that has a countable number of possible values.

# %% [markdown]
# **Definition 2.2.8**
#
# The probability mass function (pmf) of a discrete random variable
# $𝑋$ is: $ p(x) = P(X=x)$

# %% [markdown]
# **Definition 2.2.9**
#
# The cumulative distribution function (cdf) of $𝑋$ is:
# $F(x) = P(X≤x)$

# %% [markdown]
# **Example 2.2.3**
#
# Consider rolling two fair six-sided dice. Let $X$ be the sum of the two dice.
#
# 1. Possible Values of $𝑋$: $2,3,…,12$
# 2. Calculate PMF: Determine $P(X=k)$ for each possible sum $𝑘$.
# 3. Total Possible Outcomes: $6×6 = 36$
# 4. Compute Probabilities: For each sum, count the number of combinations that result in that sum.

# %%
# Possible sums when rolling two dice
sums = [i + j for i in range(1, 7) for j in range(1, 7)]

# Import Counter to count frequencies
from collections import Counter
sum_counts = Counter(sums)

# Total number of outcomes
total_outcomes = 36

# Calculate PMF
pmf = {k: v / total_outcomes for k, v in sum_counts.items()}

# Sort PMF
pmf = dict(sorted(pmf.items()))

# Display PMF
for sum_value, probability in pmf.items():
    print(f"P(X = {sum_value}) = {probability:.4f}")
# Out:
# P(X = 2) = 0.0278
# P(X = 3) = 0.0556
# P(X = 4) = 0.0833
# P(X = 5) = 0.1111
# P(X = 6) = 0.1389
# P(X = 7) = 0.1667
# P(X = 8) = 0.1389
# P(X = 9) = 0.1111
# P(X = 10) = 0.0833
# P(X = 11) = 0.0556
# P(X = 12) = 0.0278

# %%
import matplotlib.pyplot as plt

# Plot PMF
plt.bar(pmf.keys(), pmf.values(), color='skyblue')
plt.xlabel('Sum of Two Dice')
plt.ylabel('Probability')
plt.title('PMF of Sum of Two Dice')
plt.xticks(range(2, 13))
plt.show()

# %% [markdown]
# ###Expected Value and Variance

# %% [markdown]
# **Definition 2.2.7**
#
# The expected value (mean) of a discrete random variable $𝑋$ is:
# $E[X]= ∑_xx.p_X(x)$

# %% [markdown]
# **Definition 2.2.8**
#
# The variance of $𝑋$ is:
#
#
# $Var(X)=E[(X−E[X])^2]=E[X^2]−(E[X])^2$

# %%
#Expected Value and Variance for Sum of Two Dice:

# Expected Value E[X]
E_X = sum(x * p for x, p in pmf.items())
print(f"Expected Value E[X] = {E_X}")

# E[X^2]
E_X2 = sum(x**2 * p for x, p in pmf.items())

# Variance Var(X)
Var_X = E_X2 - E_X**2
print(f"Variance Var(X) = {Var_X}")
# Out:
# Expected Value E[X] = 6.999999999999999
# Variance Var(X) = 5.833333333333336

# %% [markdown]
# ## **2.2.4 Continuous Random Variables**

# %% [markdown]
# **Definition 2.2.9**
#
# A continuous random variable is one that can take on any value within an interval or collection of intervals.

# %% [markdown]
# **Probability Density Function (PDF)**
#
# The probability density function $𝑓_𝑋(𝑥)$ of a continuous random variable
# $𝑋$ satisfies:
# 1. $𝑓_𝑋(𝑥) ≥ 0$ for all $𝑥$
# 2. The total area under the curve is 1:$\int_{-\infty}^{\infty} f_X(x) \, dx = 1 $
# 3. The probability that $𝑋$ falls within the interval $[a,b]$ is: $P(a \leq X \leq b) = \int_{a}^{b} f_X(x) \, dx$

# %% [markdown]
# **Cumulative Distribution Function (CDF)**
#
# The cumulative distribution function $𝑓_𝑋(𝑥)$ is:
# $F_X(x) = P(X \leq x) = \int_{-\infty}^{x} f_X(t) \, dt$

# %% [markdown]
# **Example 2.2.4: Uniform Distribution**
#
# Suppose $𝑋$ is uniformly distributed between 0 and 1.
#
# PDF:
# * $f_X(x) = \begin{cases}
# 1, 0 \leq x \leq 1 \\
# 0, \text{otherwise}
# \end{cases}$
#
# CDF:
# * $F_X(x) = \begin{cases}
# 0,  x < 0 \\
# x, 0 \leq x \leq 1 \\
# 1,  x > 1
# \end{cases}$

# %% [markdown]
# Compute $P(0.2≤X≤0.7)$:
# * $P(0.2 \leq X \leq 0.7) = \int_{0.2}^{0.7} 1 \, dx = 0.5$

# %%
from scipy.stats import uniform

# Define the uniform distribution
a, b = 0, 1
X = uniform(loc=a, scale=b - a)

# Compute probability
P = X.cdf(0.7) - X.cdf(0.2)
print(f"P(0.2 ≤ X ≤ 0.7) = {P}")

# Plot PDF
import numpy as np
x_values = np.linspace(-0.5, 1.5, 1000)
pdf_values = X.pdf(x_values)

plt.plot(x_values, pdf_values, color='orange')
plt.title('Uniform Distribution PDF')
plt.xlabel('x')
plt.ylabel('f_X(x)')
plt.show()

# Plot CDF
cdf_values = X.cdf(x_values)

plt.plot(x_values, cdf_values, color='blue')
plt.title('Uniform Distribution CDF')
plt.xlabel('x')
plt.ylabel('F_X(x)')
plt.show()
# Out:
# P(0.2 ≤ X ≤ 0.7) = 0.49999999999999994

# %% [markdown]
# ### Normal Distribution

# %% [markdown]
# **Definition 2.2.10**
#
# A continuous random variable $𝑋$ has a normal distribution with mean $𝜇$ and standard deviation $𝜎$ if its PDF is:
#
#
# *   $f_X(x) = \frac{1}{\sigma \sqrt{2\pi}} e^{ -\frac{(x - \mu)^2}{2\sigma^2} }$
#
# When $𝜇=0$ and $σ=1$, $𝑋$ is said to have a standard normal distribution.
#
# Properties:
# 1. Symmetric about the mean $𝜇$
# 2. The total area under the curve is 1.
# 3. Approximately 68% of the data falls within one standard deviation of the mean.

# %% [markdown]
# **Example 2.2.5: Standard Normal Distribution**
#
# Compute $P(X≤1.96)$ where $𝑋$ is a standard normal random variable.
#
# Using standard normal distribution tables, $P(X≤1.96)≈0.9750$

# %%
from scipy.stats import norm

# Standard normal distribution
Z = norm(loc=0, scale=1)

# Compute P(X ≤ 1.96)
P = Z.cdf(1.96)
print(f"P(X ≤ 1.96) = {P}")

# Plot PDF
z_values = np.linspace(-4, 4, 1000)
pdf_values = Z.pdf(z_values)

plt.plot(z_values, pdf_values, color='green')
plt.title('Standard Normal Distribution PDF')
plt.xlabel('z')
plt.ylabel('f_Z(z)')
plt.show()

# Plot CDF
cdf_values = Z.cdf(z_values)

plt.plot(z_values, cdf_values, color='red')
plt.title('Standard Normal Distribution CDF')
plt.xlabel('z')
plt.ylabel('F_Z(z)')
plt.show()
# Out:
# P(X ≤ 1.96) = 0.9750021048517795

# %% [markdown]
# ### Exponential Distribution

# %% [markdown]
# **Definition 2.2.11**
#
# A continuous random variable $𝑋$ has an exponential distribution with rate parameter $λ>0$ if its PDF is:
# * $f_X(x) = \lambda e^{- \lambda x}, \quad x \geq 0$
#
# Properties:
# 1. Mean: $E[X]= 1/λ$
# 2. Variance: $Var(X)= 1/λ^2$

# %% [markdown]
# **Example 2.2.6: Exponential Distribution**
# Suppose the time between arrivals of customers at a bank follows an exponential distribution with an average rate of 3 customers per hour$(λ=3)$.
#
# Compute the probability that the next customer arrives within 10 minutes ($1/6$ hours).
#
# Solution: $P(X \leq \tfrac{1}{6}) = 1 - e^{-3 \times \tfrac{1}{6}} = 1 - e^{-0.5} \approx 0.3935 $

# %%
from scipy.stats import expon

# Rate parameter
lambda_param = 3  # per hour

# Define the exponential distribution
X = expon(scale=1 / lambda_param)

# Compute P(X ≤ 1/6)
P = X.cdf(1 / 6)
print(f"P(X ≤ 10 minutes) = {P}")

# Plot PDF
x_values = np.linspace(0, 2, 1000)
pdf_values = X.pdf(x_values)

plt.plot(x_values, pdf_values, color='purple')
plt.title('Exponential Distribution PDF')
plt.xlabel('Time (hours)')
plt.ylabel('f_X(x)')
plt.show()

# Plot CDF
cdf_values = X.cdf(x_values)

plt.plot(x_values, cdf_values, color='brown')
plt.title('Exponential Distribution CDF')
plt.xlabel('Time (hours)')
plt.ylabel('F_X(x)')
plt.show()
# Out:
# P(X ≤ 10 minutes) = 0.3934693402873666

# %% [markdown]
# ### Expected Value and Variance of Continuous Random Variables

# %% [markdown]
# **Definition 2.2.12**
#
# The expected value (mean) of a continuous random variable $𝑋$ with PDF
# $𝑓_𝑋(𝑥)$ is: $E[X] = \int_{-\infty}^{\infty} x f_X(x) \, dx$

# %% [markdown]
# **Definition 2.2.13**
#
# The variance of $𝑋$ is:
# $\text{Var}(X) = E[(X - E[X])^2] = E[X^2] - (E[X])^2$

# %% [markdown]
# **Example 2.2.7: Expected Value and Variance of Exponential Distribution**
# Using the exponential distribution with rate parameter $λ=3$:
# * Expected Value: $E[X] = \frac{1}{\lambda} = \frac{1}{3} \approx 0.3333 \text{ hours}$
# * Variance: $\text{Var}(X) = \frac{1}{\lambda^2} = \left(\frac{1}{3}\right)^2 \approx 0.1111 \text{ hours}^2$

# %%
# Mean and Variance using scipy.stats
mean_X = X.mean()
var_X = X.var()

print(f"Expected Value E[X] = {mean_X}")
print(f"Variance Var(X) = {var_X}")
# Out:
# Expected Value E[X] = 0.3333333333333333
# Variance Var(X) = 0.1111111111111111
